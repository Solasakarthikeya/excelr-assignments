# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/sales_data_with_discounts.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
mean_values = df[numerical_columns].mean()
print(mean_values)
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
mean_values = df[numerical_columns].median()
print(mean_values)
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
mean_values = df[numerical_columns].mode()
print(mean_values)
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
mean_values = df[numerical_columns].std()
print(mean_values)
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %% [markdown]
# **HISTOGRAMS WITH SKEWNESS & OUTLIERS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['Volume'])
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
skew=df['Volume'].skew()
outlier=df['Volume'].skew()
print(skew)
print(outlier)
plt.show()
# Out:
# 2.731723626557714
# 2.731723626557714

# %%
plt.hist(df['Avg Price'])
plt.title('Histogram of Avg Price')
plt.xlabel('Avg Price')
plt.ylabel('Frequency')
skew=df['Avg Price'].skew()
outlier=df['Avg Price'].skew()
print(skew)
print(outlier)
plt.show()
# Out:
# 1.9088730767759727
# 1.9088730767759727

# %%
plt.hist(df['Total Sales Value'])
plt.title('Histogram of Sales value')
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')
skew=df['Total Sales Value'].skew()
outlier=df['Total Sales Value'].skew()
print(skew)
print(outlier)
plt.show()
# Out:
# 1.5347293238977937
# 1.5347293238977937

# %%
plt.hist(df['Discount Rate (%)'])
plt.title('Histogram of discount rate')
plt.xlabel('Discount Rate (%)')
plt.ylabel('Frequency')
skew=df['Discount Rate (%)'].skew()
outlier=df['Discount Rate (%)'].skew()
print(skew)
print(outlier)
plt.show()
# Out:
# -1.0622943696988825
# -1.0622943696988825

# %%
plt.hist(df['Discount Amount'])
plt.title('Histogram of discount amount')
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')
skew=df['Discount Amount'].skew()
outlier=df['Discount Amount'].skew()
print(skew)
print(outlier)
plt.show()
# Out:
# 1.9130377339538271
# 1.9130377339538271

# %%
plt.hist(df[ 'Net Sales Value'])
plt.title('Histogram of net sales value')
plt.xlabel( 'Net Sales Value')
plt.ylabel('Frequency')
skew=df[ 'Net Sales Value'].skew()
outlier=df[ 'Net Sales Value'].skew()
print(skew)
print(outlier)
plt.show()
# Out:
# 1.5408217575344376
# 1.5408217575344376

# %% [markdown]
# **BAR PLOTS**

# %%
df['Date'].value_counts().plot.bar()
plt.title('Sales by Date')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
df['Day'].value_counts().plot.bar()
plt.title('Sales by Day')
plt.xlabel('Day')
plt.ylabel('Sales')
plt.show()

# %%
df['SKU'].value_counts().plot.bar()
plt.title('Sales by SKU')
plt.xlabel('SKU')
plt.ylabel('Sales')
plt.show()

# %%
df['City'].value_counts().plot.bar()
plt.title('Sales by City')
plt.xlabel('City')
plt.ylabel('Sales')
plt.show()

# %%
df['BU'].value_counts().plot.bar()
plt.title('Sales by BU')
plt.xlabel('BU')
plt.ylabel('Sales')
plt.show()

# %%
df['Brand'].value_counts().plot.bar()
plt.title('Sales by Brand')
plt.xlabel('Brand')
plt.ylabel('Sales')
plt.show()

# %%
df['Model'].value_counts().plot.bar()
plt.title('Sales by Model')
plt.xlabel('Model')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# **BOX PLOTS**

# %%
plt.boxplot(df['Volume'])
plt.title('Box Plot of Volume')
plt.show()

# %%
plt.boxplot(df['Avg Price'])
plt.title('Box Plot of Avg Price')
plt.show()

# %%
plt.boxplot(df['Total Sales Value'])
plt.title('Box Plot of Total Sales Value')
plt.show()

# %%
plt.boxplot(df['Discount Rate (%)'])
plt.title('Box Plot of Discount Rate (%)')
plt.show()

# %%
plt.boxplot(df['Discount Amount'])
plt.title('Box Plot of Discount Amount')
plt.show()

# %%
plt.boxplot(df['Net Sales Value'])
plt.title('Box Plot of Net Sales Value')
plt.show()

# %%
plt.boxplot(df['Discount Amount'])
plt.title('Box Plot of Discount Amount')
plt.show()

# %%
plt.boxplot(df['Net Sales Value'])
plt.title('Box Plot of Net Sales Value')
plt.show()

# %%
import scipy.stats as stats

z_scores_volume = stats.zscore(df['Volume'])
print("Z-scores for Volume:", z_scores_volume)
# Out:
# Z-scores for Volume: 0      2.350029
# 1      1.167129
# 2      0.457388
# 3      0.220808
# 4     -0.488932
#          ...
# 445   -0.725512
# 446    0.220808
# 447   -0.725512
# 448   -0.488932
# 449   -0.962092
# Name: Volume, Length: 450, dtype: float64

# %%
z_scores_avg_price = stats.zscore(df['Avg Price'])
print("Z-scores for Avg Price:", z_scores_avg_price)
# Out:
# Z-scores for Avg Price: 0      0.091173
# 1     -0.019570
# 2      0.312659
# 3      0.534146
# 4     -0.130313
#          ...
# 445   -0.506840
# 446   -0.434857
# 447   -0.490229
# 448   -0.473617
# 449   -0.407171
# Name: Avg Price, Length: 450, dtype: float64

# %%
z_scores_total_sales_value = stats.zscore(df['Total Sales Value'])
print("Z-scores for Total Sales Value:", z_scores_total_sales_value)
# Out:
# Z-scores for Total Sales Value: 0      2.925721
# 1      1.330995
# 2      1.562775
# 3      1.719276
# 4     -0.188452
#          ...
# 445   -0.618334
# 446   -0.360801
# 447   -0.606448
# 448   -0.556923
# 449   -0.608429
# Name: Total Sales Value, Length: 450, dtype: float64

# %%
z_scores_discount_rate = stats.zscore(df['Discount Rate (%)'])
print("Z-scores for Discount Rate:", z_scores_discount_rate)
# Out:
# Z-scores for Discount Rate: 0     -0.830289
# 1     -0.852661
# 2     -1.351631
# 3     -1.949723
# 4      0.673739
#          ...
# 445    0.076009
# 446    0.451097
# 447    0.903793
# 448    0.388474
# 449    0.042235
# Name: Discount Rate (%), Length: 450, dtype: float64

# %%
z_scores_discount_amount = stats.zscore(df['Discount Amount'])
print("Z-scores for Discount Amount:", z_scores_discount_amount)
# Out:
# Z-scores for Discount Amount: 0      3.952816
# 1      1.849014
# 2      1.622995
# 3      1.113807
# 4      0.227852
#          ...
# 445   -0.653541
# 446   -0.152191
# 447   -0.608140
# 448   -0.530379
# 449   -0.637345
# Name: Discount Amount, Length: 450, dtype: float64

# %%
z_scores_net_sales_value = stats.zscore(df['Net Sales Value'])
print("Z-scores for Net Sales Value:", z_scores_net_sales_value)
# Out:
# Z-scores for Net Sales Value: 0      2.804756
# 1      1.271026
# 2      1.545675
# 3      1.765810
# 4     -0.227595
#          ...
# 445   -0.610461
# 446   -0.378500
# 447   -0.601921
# 448   -0.555499
# 449   -0.601239
# Name: Net Sales Value, Length: 450, dtype: float64
